# %%
import os
import re
from pathlib import Path

# %%
# --- IMPORTANT ---
# Change this path to the root directory you want to process.
# Example for Windows: "C:/Users/YourUser/Documents/Reports"
# Example for macOS/Linux: "/home/youruser/documents/reports"

root_directory_path = r"pdf_data"

# %%
def rename_pdfs_in_structured_dirs(root_directory: str):
    """
    Scans a directory for subdirectories matching the pattern 'YEAR/YEAR QX',
    and renames PDF files within them by appending the quarter's name.
    """
    root_path = Path(root_directory)
    if not root_path.is_dir():
        print(f"Error: Directory not found at '{root_directory}'")
        return

    print(f"Starting scan in: {root_path}\n")

    # Regex to precisely match '202[1-5]' and '202[1-5] Q[1-4]'
    year_pattern = re.compile(r"^202[1-5]$")
    quarter_dir_pattern = re.compile(r"^202[1-5] Q[1-4]$")

    # Step 1: Find all potential quarterly directories using a broad glob
    for quarter_dir in root_path.glob('202*/* Q*'):
        if not quarter_dir.is_dir():
            continue

        year_dir = quarter_dir.parent

        # Step 2: Validate the folder structure with precise regex
        if year_pattern.match(year_dir.name) and quarter_dir_pattern.match(quarter_dir.name):
            print(f"--- Processing valid folder: {quarter_dir} ---")
            suffix_to_add = f" {quarter_dir.name}"

            # Step 3: Process all PDF files within the valid folder
            for pdf_path in quarter_dir.glob('*.pdf'):
                try:
                    # Safety Check: Skip already renamed files
                    if suffix_to_add in pdf_path.stem:
                        print(f"  Skipping (already renamed): {pdf_path.name}")
                        continue

                    new_path = pdf_path.with_stem(f"{pdf_path.stem}{suffix_to_add}")
                    print(f"  Renaming: '{pdf_path.name}' -> '{new_path.name}'")
                    pdf_path.rename(new_path)

                except Exception as e:
                    print(f"  An unexpected error occurred with file {pdf_path.name}: {e}")
            print("-" * (len(str(quarter_dir)) + 24))

    print("\nScan complete.")

# %%
# Call the function to start the process
rename_pdfs_in_structured_dirs(root_directory_path)
# Out:
# Starting scan in: pdf_data
#
# --- Processing valid folder: pdf_data\2021\2021 Q1 ---
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2021\2021 Q2 ---
#   Renaming: 'Tri Valley.pdf' -> 'Tri Valley 2021 Q2.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2021\2021 Q3 ---
#   Renaming: 'San Francisco Peninsula Snapshot.pdf' -> 'San Francisco Peninsula Snapshot 2021 Q3.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2021 Q3.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2021\2021 Q4 ---
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2022\2022 Q1 ---
#   Renaming: 'Boston.pdf' -> 'Boston 2022 Q1.pdf'
#   Renaming: 'Raleigh Durham.pdf' -> 'Raleigh Durham 2022 Q1.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2022\2022 Q2 ---
#   Renaming: 'Tulsa.pdf' -> 'Tulsa 2022 Q2.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2022\2022 Q3 ---
#   Renaming: 'Raleigh Durham.pdf' -> 'Raleigh Durham 2022 Q3.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2022\2022 Q4 ---
#   Renaming: 'Austin.pdf' -> 'Austin 2022 Q4.pdf'
#   Renaming: 'Baltimore.pdf' -> 'Baltimore 2022 Q4.pdf'
#   Renaming: 'Charlotte.pdf' -> 'Charlotte 2022 Q4.pdf'
#   Renaming: 'Cleveland.pdf' -> 'Cleveland 2022 Q4.pdf'
#   Renaming: 'Columbus.pdf' -> 'Columbus 2022 Q4.pdf'
#   Renaming: 'Dallas Fort Worth.pdf' -> 'Dallas Fort Worth 2022 Q4.pdf'
#   Renaming: 'Denver.pdf' -> 'Denver 2022 Q4.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2022 Q4.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2022 Q4.pdf'
#   Renaming: 'Raleigh Durham.pdf' -> 'Raleigh Durham 2022 Q4.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2022 Q4.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2023\2023 Q1 ---
#   Renaming: 'Boston.pdf' -> 'Boston 2023 Q1.pdf'
#   Renaming: 'Broward.pdf' -> 'Broward 2023 Q1.pdf'
#   Renaming: 'Dallas Fort Worth.pdf' -> 'Dallas Fort Worth 2023 Q1.pdf'
#   Renaming: 'Nashville.pdf' -> 'Nashville 2023 Q1.pdf'
#   Renaming: 'Oklahoma City.pdf' -> 'Oklahoma City 2023 Q1.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2023 Q1.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2023 Q1.pdf'
#   Renaming: 'Silicon Valley.pdf' -> 'Silicon Valley 2023 Q1.pdf'
#   Renaming: 'Tulsa.pdf' -> 'Tulsa 2023 Q1.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2023\2023 Q2 ---
#   Renaming: 'Albuquerque.pdf' -> 'Albuquerque 2023 Q2.pdf'
#   Renaming: 'Atlanta.pdf' -> 'Atlanta 2023 Q2.pdf'
#   Renaming: 'Austin.pdf' -> 'Austin 2023 Q2.pdf'
#   Renaming: 'Baltimore.pdf' -> 'Baltimore 2023 Q2.pdf'
#   Renaming: 'Boise.pdf' -> 'Boise 2023 Q2.pdf'
#   Renaming: 'Boston.pdf' -> 'Boston 2023 Q2.pdf'
#   Renaming: 'Broward.pdf' -> 'Broward 2023 Q2.pdf'
#   Renaming: 'Central Valley.pdf' -> 'Central Valley 2023 Q2.pdf'
#   Renaming: 'Charleston.pdf' -> 'Charleston 2023 Q2.pdf'
#   Renaming: 'Charlotte.pdf' -> 'Charlotte 2023 Q2.pdf'
#   Renaming: 'Cincinnati.pdf' -> 'Cincinnati 2023 Q2.pdf'
#   Renaming: 'Cleveland.pdf' -> 'Cleveland 2023 Q2.pdf'
#   Renaming: 'Colorado Springs.pdf' -> 'Colorado Springs 2023 Q2.pdf'
#   Renaming: 'Columbus.pdf' -> 'Columbus 2023 Q2.pdf'
#   Renaming: 'Des Moines.pdf' -> 'Des Moines 2023 Q2.pdf'
#   Renaming: 'Detroit.pdf' -> 'Detroit 2023 Q2.pdf'
#   Renaming: 'El Paso.pdf' -> 'El Paso 2023 Q2.pdf'
#   Renaming: 'Greater Los Angeles.pdf' -> 'Greater Los Angeles 2023 Q2.pdf'
#   Renaming: 'Hartford.pdf' -> 'Hartford 2023 Q2.pdf'
#   Renaming: 'Houston.pdf' -> 'Houston 2023 Q2.pdf'
#   Renaming: 'Indianapolis.pdf' -> 'Indianapolis 2023 Q2.pdf'
#   Renaming: 'Inland Empire.pdf' -> 'Inland Empire 2023 Q2.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2023 Q2.pdf'
#   Renaming: 'Kansas City.pdf' -> 'Kansas City 2023 Q2.pdf'
#   Renaming: 'Long Island.pdf' -> 'Long Island 2023 Q2.pdf'
#   Renaming: 'Louisville.pdf' -> 'Louisville 2023 Q2.pdf'
#   Renaming: 'McAllen.pdf' -> 'McAllen 2023 Q2.pdf'
#   Renaming: 'Memphis.pdf' -> 'Memphis 2023 Q2.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2023 Q2.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2023 Q2.pdf'
#   Renaming: 'Minneapolis.pdf' -> 'Minneapolis 2023 Q2.pdf'
#   Renaming: 'Napa Solano.pdf' -> 'Napa Solano 2023 Q2.pdf'
#   Renaming: 'Nashville.pdf' -> 'Nashville 2023 Q2.pdf'
#   Renaming: 'New York City.pdf' -> 'New York City 2023 Q2.pdf'
#   Renaming: 'North East Contra Costa County.pdf' -> 'North East Contra Costa County 2023 Q2.pdf'
#   Renaming: 'Northern California Do Alone.pdf' -> 'Northern California Do Alone 2023 Q2.pdf'
#   Renaming: 'Northern Virginia.pdf' -> 'Northern Virginia 2023 Q2.pdf'
#   Renaming: 'Oakland.pdf' -> 'Oakland 2023 Q2.pdf'
#   Renaming: 'Omaha.pdf' -> 'Omaha 2023 Q2.pdf'
#   Renaming: 'Orange County.pdf' -> 'Orange County 2023 Q2.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2023 Q2.pdf'
#   Renaming: 'PA I-78 I-81 Corridor.pdf' -> 'PA I-78 I-81 Corridor 2023 Q2.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2023 Q2.pdf'
#   Renaming: 'Phoenix.pdf' -> 'Phoenix 2023 Q2.pdf'
#   Renaming: 'Pittsburg.pdf' -> 'Pittsburg 2023 Q2.pdf'
#   Renaming: 'Polk County.pdf' -> 'Polk County 2023 Q2.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2023 Q2.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2023 Q2.pdf'
#   Renaming: 'Reno.pdf' -> 'Reno 2023 Q2.pdf'
#   Renaming: 'Sacramento Snapshot.pdf' -> 'Sacramento Snapshot 2023 Q2.pdf'
#   Renaming: 'Sacramento.pdf' -> 'Sacramento 2023 Q2.pdf'
#   Renaming: 'Salt Lake City.pdf' -> 'Salt Lake City 2023 Q2.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2023 Q2.pdf'
#   Renaming: 'San Francisco Peninsula.pdf' -> 'San Francisco Peninsula 2023 Q2.pdf'
#   Renaming: 'San Francisco.pdf' -> 'San Francisco 2023 Q2.pdf'
#   Renaming: 'Silicon Valley.pdf' -> 'Silicon Valley 2023 Q2.pdf'
#   Renaming: 'South Central Valley.pdf' -> 'South Central Valley 2023 Q2.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2023 Q2.pdf'
#   Renaming: 'Tri Valley.pdf' -> 'Tri Valley 2023 Q2.pdf'
#   Renaming: 'Tucson.pdf' -> 'Tucson 2023 Q2.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2023\2023 Q3 ---
#   Renaming: 'Broward.pdf' -> 'Broward 2023 Q3.pdf'
#   Renaming: 'Columbia.pdf' -> 'Columbia 2023 Q3.pdf'
#   Renaming: 'Hawaii.pdf' -> 'Hawaii 2023 Q3.pdf'
#   Renaming: 'Houston.pdf' -> 'Houston 2023 Q3.pdf'
#   Renaming: 'Inland Empire.pdf' -> 'Inland Empire 2023 Q3.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2023 Q3.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2023 Q3.pdf'
#   Renaming: 'New York City.pdf' -> 'New York City 2023 Q3.pdf'
#   Renaming: 'North East.pdf' -> 'North East 2023 Q3.pdf'
#   Renaming: 'Orange County.pdf' -> 'Orange County 2023 Q3.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2023 Q3.pdf'
#   Renaming: 'PA I-78 I-81 Corridor.pdf' -> 'PA I-78 I-81 Corridor 2023 Q3.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2023 Q3.pdf'
#   Renaming: 'Polk County.pdf' -> 'Polk County 2023 Q3.pdf'
#   Renaming: 'St Louis.pdf' -> 'St Louis 2023 Q3.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2023 Q3.pdf'
#   Renaming: 'United States.pdf' -> 'United States 2023 Q3.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2023\2023 Q4 ---
#   Renaming: 'Albuquerque.pdf' -> 'Albuquerque 2023 Q4.pdf'
#   Renaming: 'Austin.pdf' -> 'Austin 2023 Q4.pdf'
#   Renaming: 'Broward.pdf' -> 'Broward 2023 Q4.pdf'
#   Renaming: 'Chicago.pdf' -> 'Chicago 2023 Q4.pdf'
#   Renaming: 'Cincinnati.pdf' -> 'Cincinnati 2023 Q4.pdf'
#   Renaming: 'Dallas Fort Worth.pdf' -> 'Dallas Fort Worth 2023 Q4.pdf'
#   Renaming: 'Des Moines.pdf' -> 'Des Moines 2023 Q4.pdf'
#   Renaming: 'Hartford.pdf' -> 'Hartford 2023 Q4.pdf'
#   Renaming: 'Hawaii.pdf' -> 'Hawaii 2023 Q4.pdf'
#   Renaming: 'Indianapolis.pdf' -> 'Indianapolis 2023 Q4.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2023 Q4.pdf'
#   Renaming: 'McAllen.pdf' -> 'McAllen 2023 Q4.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2023 Q4.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2023 Q4.pdf'
#   Renaming: 'Norfolk.pdf' -> 'Norfolk 2023 Q4.pdf'
#   Renaming: 'North East Contra Costa County.pdf' -> 'North East Contra Costa County 2023 Q4.pdf'
#   Renaming: 'Northern and Central New Jersey.pdf' -> 'Northern and Central New Jersey 2023 Q4.pdf'
#   Renaming: 'Northern Virginia.pdf' -> 'Northern Virginia 2023 Q4.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2023 Q4.pdf'
#   Renaming: 'PA I-78 I-81 Corridor.pdf' -> 'PA I-78 I-81 Corridor 2023 Q4.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2023 Q4.pdf'
#   Renaming: 'Pittsburg.pdf' -> 'Pittsburg 2023 Q4.pdf'
#   Renaming: 'Polk County.pdf' -> 'Polk County 2023 Q4.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2023 Q4.pdf'
#   Renaming: 'Reno.pdf' -> 'Reno 2023 Q4.pdf'
#   Renaming: 'Richmond.pdf' -> 'Richmond 2023 Q4.pdf'
#   Renaming: 'Sacramento Snapshot.pdf' -> 'Sacramento Snapshot 2023 Q4.pdf'
#   Renaming: 'Sacramento.pdf' -> 'Sacramento 2023 Q4.pdf'
#   Renaming: 'Salt Lake City.pdf' -> 'Salt Lake City 2023 Q4.pdf'
#   Renaming: 'San Francisco.pdf' -> 'San Francisco 2023 Q4.pdf'
#   Renaming: 'St Louis.pdf' -> 'St Louis 2023 Q4.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2023 Q4.pdf'
#   Renaming: 'United States.pdf' -> 'United States 2023 Q4.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2024\2024 Q1 ---
#   Renaming: 'Albuquerque.pdf' -> 'Albuquerque 2024 Q1.pdf'
#   Renaming: 'Austin.pdf' -> 'Austin 2024 Q1.pdf'
#   Renaming: 'Baltimore.pdf' -> 'Baltimore 2024 Q1.pdf'
#   Renaming: 'Boise.pdf' -> 'Boise 2024 Q1.pdf'
#   Renaming: 'Boston.pdf' -> 'Boston 2024 Q1.pdf'
#   Renaming: 'Central Los Angeles.pdf' -> 'Central Los Angeles 2024 Q1.pdf'
#   Renaming: 'Central Valley.pdf' -> 'Central Valley 2024 Q1.pdf'
#   Renaming: 'Charleston.pdf' -> 'Charleston 2024 Q1.pdf'
#   Renaming: 'Chicago.pdf' -> 'Chicago 2024 Q1.pdf'
#   Renaming: 'Cincinnati.pdf' -> 'Cincinnati 2024 Q1.pdf'
#   Renaming: 'Cleveland.pdf' -> 'Cleveland 2024 Q1.pdf'
#   Renaming: 'Columbia.pdf' -> 'Columbia 2024 Q1.pdf'
#   Renaming: 'Columbus.pdf' -> 'Columbus 2024 Q1.pdf'
#   Renaming: 'Dallas Fort Worth.pdf' -> 'Dallas Fort Worth 2024 Q1.pdf'
#   Renaming: 'Denver.pdf' -> 'Denver 2024 Q1.pdf'
#   Renaming: 'Des Moines.pdf' -> 'Des Moines 2024 Q1.pdf'
#   Renaming: 'Detroit.pdf' -> 'Detroit 2024 Q1.pdf'
#   Renaming: 'El Paso.pdf' -> 'El Paso 2024 Q1.pdf'
#   Renaming: 'Greater Los Angeles Snapshot.pdf' -> 'Greater Los Angeles Snapshot 2024 Q1.pdf'
#   Renaming: 'Greater Los Angeles.pdf' -> 'Greater Los Angeles 2024 Q1.pdf'
#   Renaming: 'Greater San Fernando.pdf' -> 'Greater San Fernando 2024 Q1.pdf'
#   Renaming: 'Greenville Spartanburg.pdf' -> 'Greenville Spartanburg 2024 Q1.pdf'
#   Renaming: 'Hawaii.pdf' -> 'Hawaii 2024 Q1.pdf'
#   Renaming: 'Indianapolis.pdf' -> 'Indianapolis 2024 Q1.pdf'
#   Renaming: 'Inland Empire.pdf' -> 'Inland Empire 2024 Q1.pdf'
#   Renaming: 'Kansas City.pdf' -> 'Kansas City 2024 Q1.pdf'
#   Renaming: 'Laredo.pdf' -> 'Laredo 2024 Q1.pdf'
#   Renaming: 'Las Vegas.pdf' -> 'Las Vegas 2024 Q1.pdf'
#   Renaming: 'Louisville.pdf' -> 'Louisville 2024 Q1.pdf'
#   Renaming: 'McAllen.pdf' -> 'McAllen 2024 Q1.pdf'
#   Renaming: 'Midwest.pdf' -> 'Midwest 2024 Q1.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2024 Q1.pdf'
#   Renaming: 'Minneapolis.pdf' -> 'Minneapolis 2024 Q1.pdf'
#   Renaming: 'Napa Solano.pdf' -> 'Napa Solano 2024 Q1.pdf'
#   Renaming: 'New York CIty.pdf' -> 'New York CIty 2024 Q1.pdf'
#   Renaming: 'Norfolk.pdf' -> 'Norfolk 2024 Q1.pdf'
#   Renaming: 'North East Contra Costa County.pdf' -> 'North East Contra Costa County 2024 Q1.pdf'
#   Renaming: 'Northern Virginia.pdf' -> 'Northern Virginia 2024 Q1.pdf'
#   Renaming: 'Oakland.pdf' -> 'Oakland 2024 Q1.pdf'
#   Renaming: 'Omaha.pdf' -> 'Omaha 2024 Q1.pdf'
#   Renaming: 'Orange County.pdf' -> 'Orange County 2024 Q1.pdf'
#   Renaming: 'Panhandle.pdf' -> 'Panhandle 2024 Q1.pdf'
#   Renaming: 'Phoenix.pdf' -> 'Phoenix 2024 Q1.pdf'
#   Renaming: 'Pittsburgh.pdf' -> 'Pittsburgh 2024 Q1.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2024 Q1.pdf'
#   Renaming: 'Reno.pdf' -> 'Reno 2024 Q1.pdf'
#   Renaming: 'Richmond.pdf' -> 'Richmond 2024 Q1.pdf'
#   Renaming: 'Sacramento.pdf' -> 'Sacramento 2024 Q1.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2024 Q1.pdf'
#   Renaming: 'San Francisco Peninsula.pdf' -> 'San Francisco Peninsula 2024 Q1.pdf'
#   Renaming: 'San Francisco.pdf' -> 'San Francisco 2024 Q1.pdf'
#   Renaming: 'San Gabriel Valley.pdf' -> 'San Gabriel Valley 2024 Q1.pdf'
#   Renaming: 'Silicon Valley.pdf' -> 'Silicon Valley 2024 Q1.pdf'
#   Renaming: 'South Bay.pdf' -> 'South Bay 2024 Q1.pdf'
#   Renaming: 'South Central Valley.pdf' -> 'South Central Valley 2024 Q1.pdf'
#   Renaming: 'St Louis.pdf' -> 'St Louis 2024 Q1.pdf'
#   Renaming: 'Suburban Maryland.pdf' -> 'Suburban Maryland 2024 Q1.pdf'
#   Renaming: 'Tri Valley.pdf' -> 'Tri Valley 2024 Q1.pdf'
#   Renaming: 'Tucson.pdf' -> 'Tucson 2024 Q1.pdf'
#   Renaming: 'Ventura.pdf' -> 'Ventura 2024 Q1.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2024\2024 Q2 ---
#   Renaming: 'Austin.pdf' -> 'Austin 2024 Q2.pdf'
#   Renaming: 'Broward.pdf' -> 'Broward 2024 Q2.pdf'
#   Renaming: 'Colorado Springs.pdf' -> 'Colorado Springs 2024 Q2.pdf'
#   Renaming: 'Greater Los Angeles.pdf' -> 'Greater Los Angeles 2024 Q2.pdf'
#   Renaming: 'Hawaii.pdf' -> 'Hawaii 2024 Q2.pdf'
#   Renaming: 'Houston.pdf' -> 'Houston 2024 Q2.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2024 Q2.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2024 Q2.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2024 Q2.pdf'
#   Renaming: 'Northern and Central New Jersey.pdf' -> 'Northern and Central New Jersey 2024 Q2.pdf'
#   Renaming: 'Northern Colorado.pdf' -> 'Northern Colorado 2024 Q2.pdf'
#   Renaming: 'Oakland.pdf' -> 'Oakland 2024 Q2.pdf'
#   Renaming: 'Oklahoma City.pdf' -> 'Oklahoma City 2024 Q2.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2024 Q2.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2024 Q2.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2024 Q2.pdf'
#   Renaming: 'Tulsa.pdf' -> 'Tulsa 2024 Q2.pdf'
#   Renaming: 'United States.pdf' -> 'United States 2024 Q2.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2024\2024 Q3 ---
#   Renaming: 'Albuquerque.pdf' -> 'Albuquerque 2024 Q3.pdf'
#   Renaming: 'Atlanta.pdf' -> 'Atlanta 2024 Q3.pdf'
#   Renaming: 'Austin.pdf' -> 'Austin 2024 Q3.pdf'
#   Renaming: 'Baltimore.pdf' -> 'Baltimore 2024 Q3.pdf'
#   Renaming: 'Boise.pdf' -> 'Boise 2024 Q3.pdf'
#   Renaming: 'Boston.pdf' -> 'Boston 2024 Q3.pdf'
#   Renaming: 'Central Los Angeles.pdf' -> 'Central Los Angeles 2024 Q3.pdf'
#   Renaming: 'Central Valley.pdf' -> 'Central Valley 2024 Q3.pdf'
#   Renaming: 'Charleston.pdf' -> 'Charleston 2024 Q3.pdf'
#   Renaming: 'Charlotte.pdf' -> 'Charlotte 2024 Q3.pdf'
#   Renaming: 'Chicago.pdf' -> 'Chicago 2024 Q3.pdf'
#   Renaming: 'Cincinnati.pdf' -> 'Cincinnati 2024 Q3.pdf'
#   Renaming: 'Cleveland.pdf' -> 'Cleveland 2024 Q3.pdf'
#   Renaming: 'Colorado Springs.pdf' -> 'Colorado Springs 2024 Q3.pdf'
#   Renaming: 'Columbus.pdf' -> 'Columbus 2024 Q3.pdf'
#   Renaming: 'Denver.pdf' -> 'Denver 2024 Q3.pdf'
#   Renaming: 'Des Moines.pdf' -> 'Des Moines 2024 Q3.pdf'
#   Renaming: 'Detroit.pdf' -> 'Detroit 2024 Q3.pdf'
#   Renaming: 'El Paso.pdf' -> 'El Paso 2024 Q3.pdf'
#   Renaming: 'Greater Los Angeles Snapshot.pdf' -> 'Greater Los Angeles Snapshot 2024 Q3.pdf'
#   Renaming: 'Greater Los Angeles.pdf' -> 'Greater Los Angeles 2024 Q3.pdf'
#   Renaming: 'Greensboro Winston Salem.pdf' -> 'Greensboro Winston Salem 2024 Q3.pdf'
#   Renaming: 'Hartford.pdf' -> 'Hartford 2024 Q3.pdf'
#   Renaming: 'Houston.pdf' -> 'Houston 2024 Q3.pdf'
#   Renaming: 'Indianapolis.pdf' -> 'Indianapolis 2024 Q3.pdf'
#   Renaming: 'Inland Empire East.pdf' -> 'Inland Empire East 2024 Q3.pdf'
#   Renaming: 'Inland Empire West.pdf' -> 'Inland Empire West 2024 Q3.pdf'
#   Renaming: 'Inland Empire.pdf' -> 'Inland Empire 2024 Q3.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2024 Q3.pdf'
#   Renaming: 'Kansas City.pdf' -> 'Kansas City 2024 Q3.pdf'
#   Renaming: 'Las Vegas.pdf' -> 'Las Vegas 2024 Q3.pdf'
#   Renaming: 'Long Island.pdf' -> 'Long Island 2024 Q3.pdf'
#   Renaming: 'Lousiville.pdf' -> 'Lousiville 2024 Q3.pdf'
#   Renaming: 'McAllen.pdf' -> 'McAllen 2024 Q3.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2024 Q3.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2024 Q3.pdf'
#   Renaming: 'Minneapolis.pdf' -> 'Minneapolis 2024 Q3.pdf'
#   Renaming: 'Napa Solano.pdf' -> 'Napa Solano 2024 Q3.pdf'
#   Renaming: 'Nashville.pdf' -> 'Nashville 2024 Q3.pdf'
#   Renaming: 'New York City.pdf' -> 'New York City 2024 Q3.pdf'
#   Renaming: 'Norfolk.pdf' -> 'Norfolk 2024 Q3.pdf'
#   Renaming: 'North East Contra Costa County.pdf' -> 'North East Contra Costa County 2024 Q3.pdf'
#   Renaming: 'Northern and Central New Jersey.pdf' -> 'Northern and Central New Jersey 2024 Q3.pdf'
#   Renaming: 'Northern Colorado.pdf' -> 'Northern Colorado 2024 Q3.pdf'
#   Renaming: 'Northern Virginia.pdf' -> 'Northern Virginia 2024 Q3.pdf'
#   Renaming: 'Oakland.pdf' -> 'Oakland 2024 Q3.pdf'
#   Renaming: 'Omaha.pdf' -> 'Omaha 2024 Q3.pdf'
#   Renaming: 'Orange County.pdf' -> 'Orange County 2024 Q3.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2024 Q3.pdf'
#   Renaming: 'PA I-78 I-81 Corridor.pdf' -> 'PA I-78 I-81 Corridor 2024 Q3.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2024 Q3.pdf'
#   Renaming: 'Philadelphia.pdf' -> 'Philadelphia 2024 Q3.pdf'
#   Renaming: 'Phoenix.pdf' -> 'Phoenix 2024 Q3.pdf'
#   Renaming: 'Pittsburgh.pdf' -> 'Pittsburgh 2024 Q3.pdf'
#   Renaming: 'Polk.pdf' -> 'Polk 2024 Q3.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2024 Q3.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2024 Q3.pdf'
#   Renaming: 'Raleigh Durham.pdf' -> 'Raleigh Durham 2024 Q3.pdf'
#   Renaming: 'Reno.pdf' -> 'Reno 2024 Q3.pdf'
#   Renaming: 'Richmond.pdf' -> 'Richmond 2024 Q3.pdf'
#   Renaming: 'Sacramento Snapshot.pdf' -> 'Sacramento Snapshot 2024 Q3.pdf'
#   Renaming: 'Sacramento.pdf' -> 'Sacramento 2024 Q3.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2024 Q3.pdf'
#   Renaming: 'San Diego.pdf' -> 'San Diego 2024 Q3.pdf'
#   Renaming: 'San Francisco Peninsula.pdf' -> 'San Francisco Peninsula 2024 Q3.pdf'
#   Renaming: 'San Francisco.pdf' -> 'San Francisco 2024 Q3.pdf'
#   Renaming: 'Silicon Valley.pdf' -> 'Silicon Valley 2024 Q3.pdf'
#   Renaming: 'South Central Valley.pdf' -> 'South Central Valley 2024 Q3.pdf'
#   Renaming: 'St Louis.pdf' -> 'St Louis 2024 Q3.pdf'
#   Renaming: 'Suburban Maryland.pdf' -> 'Suburban Maryland 2024 Q3.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2024 Q3.pdf'
#   Renaming: 'Tri Valley.pdf' -> 'Tri Valley 2024 Q3.pdf'
#   Renaming: 'Tucson.pdf' -> 'Tucson 2024 Q3.pdf'
#   Renaming: 'Tulsa.pdf' -> 'Tulsa 2024 Q3.pdf'
#   Renaming: 'Ventura.pdf' -> 'Ventura 2024 Q3.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2024\2024 Q4 ---
#   Renaming: 'Albuquerque.pdf' -> 'Albuquerque 2024 Q4.pdf'
#   Renaming: 'Atlanta.pdf' -> 'Atlanta 2024 Q4.pdf'
#   Renaming: 'Austin.pdf' -> 'Austin 2024 Q4.pdf'
#   Renaming: 'Baltimore.pdf' -> 'Baltimore 2024 Q4.pdf'
#   Renaming: 'Boise.pdf' -> 'Boise 2024 Q4.pdf'
#   Renaming: 'Boston.pdf' -> 'Boston 2024 Q4.pdf'
#   Renaming: 'Central Los Angeles.pdf' -> 'Central Los Angeles 2024 Q4.pdf'
#   Renaming: 'Central Valley.pdf' -> 'Central Valley 2024 Q4.pdf'
#   Renaming: 'Charleston.pdf' -> 'Charleston 2024 Q4.pdf'
#   Renaming: 'Charlotte.pdf' -> 'Charlotte 2024 Q4.pdf'
#   Renaming: 'Chicago.pdf' -> 'Chicago 2024 Q4.pdf'
#   Renaming: 'Cincinnati.pdf' -> 'Cincinnati 2024 Q4.pdf'
#   Renaming: 'Cleveland.pdf' -> 'Cleveland 2024 Q4.pdf'
#   Renaming: 'Columbus.pdf' -> 'Columbus 2024 Q4.pdf'
#   Renaming: 'Denver.pdf' -> 'Denver 2024 Q4.pdf'
#   Renaming: 'Des Moines.pdf' -> 'Des Moines 2024 Q4.pdf'
#   Renaming: 'Detroit.pdf' -> 'Detroit 2024 Q4.pdf'
#   Renaming: 'El Paso.pdf' -> 'El Paso 2024 Q4.pdf'
#   Renaming: 'Greater Los Angeles Snapshot.pdf' -> 'Greater Los Angeles Snapshot 2024 Q4.pdf'
#   Renaming: 'Greater Los Angeles.pdf' -> 'Greater Los Angeles 2024 Q4.pdf'
#   Renaming: 'Greensboro Winston Salem.pdf' -> 'Greensboro Winston Salem 2024 Q4.pdf'
#   Renaming: 'Hartford.pdf' -> 'Hartford 2024 Q4.pdf'
#   Renaming: 'Houston.pdf' -> 'Houston 2024 Q4.pdf'
#   Renaming: 'Indianapolis.pdf' -> 'Indianapolis 2024 Q4.pdf'
#   Renaming: 'Inland Empire East.pdf' -> 'Inland Empire East 2024 Q4.pdf'
#   Renaming: 'Inland Empire West.pdf' -> 'Inland Empire West 2024 Q4.pdf'
#   Renaming: 'Inland Empire.pdf' -> 'Inland Empire 2024 Q4.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2024 Q4.pdf'
#   Renaming: 'Kansas City.pdf' -> 'Kansas City 2024 Q4.pdf'
#   Renaming: 'Las Vegas.pdf' -> 'Las Vegas 2024 Q4.pdf'
#   Renaming: 'Long Island.pdf' -> 'Long Island 2024 Q4.pdf'
#   Renaming: 'Louisville.pdf' -> 'Louisville 2024 Q4.pdf'
#   Renaming: 'McAllen.pdf' -> 'McAllen 2024 Q4.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2024 Q4.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2024 Q4.pdf'
#   Renaming: 'Minneapolis.pdf' -> 'Minneapolis 2024 Q4.pdf'
#   Renaming: 'Napa Solano.pdf' -> 'Napa Solano 2024 Q4.pdf'
#   Renaming: 'Nashville.pdf' -> 'Nashville 2024 Q4.pdf'
#   Renaming: 'New York CIty.pdf' -> 'New York CIty 2024 Q4.pdf'
#   Renaming: 'Norfolk.pdf' -> 'Norfolk 2024 Q4.pdf'
#   Renaming: 'North East Contra Costa County.pdf' -> 'North East Contra Costa County 2024 Q4.pdf'
#   Renaming: 'Northern and Central New Jersey.pdf' -> 'Northern and Central New Jersey 2024 Q4.pdf'
#   Renaming: 'Northern Virginia.pdf' -> 'Northern Virginia 2024 Q4.pdf'
#   Renaming: 'Oakland.pdf' -> 'Oakland 2024 Q4.pdf'
#   Renaming: 'Omaha.pdf' -> 'Omaha 2024 Q4.pdf'
#   Renaming: 'Orange County.pdf' -> 'Orange County 2024 Q4.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2024 Q4.pdf'
#   Renaming: 'PA I-78 I-81 Corridor.pdf' -> 'PA I-78 I-81 Corridor 2024 Q4.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2024 Q4.pdf'
#   Renaming: 'Panhandle.pdf' -> 'Panhandle 2024 Q4.pdf'
#   Renaming: 'Philadelphia.pdf' -> 'Philadelphia 2024 Q4.pdf'
#   Renaming: 'Phoenix.pdf' -> 'Phoenix 2024 Q4.pdf'
#   Renaming: 'Pittsburgh.pdf' -> 'Pittsburgh 2024 Q4.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2024 Q4.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2024 Q4.pdf'
#   Renaming: 'Raleigh Durham.pdf' -> 'Raleigh Durham 2024 Q4.pdf'
#   Renaming: 'Reno.pdf' -> 'Reno 2024 Q4.pdf'
#   Renaming: 'Richmond.pdf' -> 'Richmond 2024 Q4.pdf'
#   Renaming: 'Sacramento.pdf' -> 'Sacramento 2024 Q4.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2024 Q4.pdf'
#   Renaming: 'San Francisco Peninsula.pdf' -> 'San Francisco Peninsula 2024 Q4.pdf'
#   Renaming: 'San Francisco.pdf' -> 'San Francisco 2024 Q4.pdf'
#   Renaming: 'Silicon Valley Snapshot.pdf' -> 'Silicon Valley Snapshot 2024 Q4.pdf'
#   Renaming: 'South Central Valley.pdf' -> 'South Central Valley 2024 Q4.pdf'
#   Renaming: 'St Louis.pdf' -> 'St Louis 2024 Q4.pdf'
#   Renaming: 'Suburban Maryland.pdf' -> 'Suburban Maryland 2024 Q4.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2024 Q4.pdf'
#   Renaming: 'Tri Valley.pdf' -> 'Tri Valley 2024 Q4.pdf'
#   Renaming: 'Tucson.pdf' -> 'Tucson 2024 Q4.pdf'
#   Renaming: 'Ventura.pdf' -> 'Ventura 2024 Q4.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2025\2025 Q1 ---
#   Renaming: 'Albuquerque.pdf' -> 'Albuquerque 2025 Q1.pdf'
#   Renaming: 'Atlanta.pdf' -> 'Atlanta 2025 Q1.pdf'
#   Renaming: 'Austin.pdf' -> 'Austin 2025 Q1.pdf'
#   Renaming: 'Baltimore.pdf' -> 'Baltimore 2025 Q1.pdf'
#   Renaming: 'Boise.pdf' -> 'Boise 2025 Q1.pdf'
#   Renaming: 'Boston.pdf' -> 'Boston 2025 Q1.pdf'
#   Renaming: 'Broward.pdf' -> 'Broward 2025 Q1.pdf'
#   Renaming: 'Central Los Angeles.pdf' -> 'Central Los Angeles 2025 Q1.pdf'
#   Renaming: 'Central Valley.pdf' -> 'Central Valley 2025 Q1.pdf'
#   Renaming: 'Charleston.pdf' -> 'Charleston 2025 Q1.pdf'
#   Renaming: 'Charlotte.pdf' -> 'Charlotte 2025 Q1.pdf'
#   Renaming: 'Chicago.pdf' -> 'Chicago 2025 Q1.pdf'
#   Renaming: 'Cincinnati.pdf' -> 'Cincinnati 2025 Q1.pdf'
#   Renaming: 'Cleveland.pdf' -> 'Cleveland 2025 Q1.pdf'
#   Renaming: 'Columbus.pdf' -> 'Columbus 2025 Q1.pdf'
#   Renaming: 'Dallas Fort Worth.pdf' -> 'Dallas Fort Worth 2025 Q1.pdf'
#   Renaming: 'Denver.pdf' -> 'Denver 2025 Q1.pdf'
#   Renaming: 'Des Moines.pdf' -> 'Des Moines 2025 Q1.pdf'
#   Renaming: 'Detroit.pdf' -> 'Detroit 2025 Q1.pdf'
#   Renaming: 'El Paso.pdf' -> 'El Paso 2025 Q1.pdf'
#   Renaming: 'Greater Los Angeles Snapshot.pdf' -> 'Greater Los Angeles Snapshot 2025 Q1.pdf'
#   Renaming: 'Greater Los Angeles.pdf' -> 'Greater Los Angeles 2025 Q1.pdf'
#   Renaming: 'Greensboro Winston Salem.pdf' -> 'Greensboro Winston Salem 2025 Q1.pdf'
#   Renaming: 'Greenville Spartanburg.pdf' -> 'Greenville Spartanburg 2025 Q1.pdf'
#   Renaming: 'Hartford.pdf' -> 'Hartford 2025 Q1.pdf'
#   Renaming: 'Hawaii.pdf' -> 'Hawaii 2025 Q1.pdf'
#   Renaming: 'Houston.pdf' -> 'Houston 2025 Q1.pdf'
#   Renaming: 'Indianapolis.pdf' -> 'Indianapolis 2025 Q1.pdf'
#   Renaming: 'Inland Empire.pdf' -> 'Inland Empire 2025 Q1.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2025 Q1.pdf'
#   Renaming: 'Kansas City.pdf' -> 'Kansas City 2025 Q1.pdf'
#   Renaming: 'Las Vegas.pdf' -> 'Las Vegas 2025 Q1.pdf'
#   Renaming: 'Long Island.pdf' -> 'Long Island 2025 Q1.pdf'
#   Renaming: 'Louisville.pdf' -> 'Louisville 2025 Q1.pdf'
#   Renaming: 'McAllen.pdf' -> 'McAllen 2025 Q1.pdf'
#   Renaming: 'Memphis.pdf' -> 'Memphis 2025 Q1.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2025 Q1.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2025 Q1.pdf'
#   Renaming: 'Minneapolis.pdf' -> 'Minneapolis 2025 Q1.pdf'
#   Renaming: 'Napa Solano.pdf' -> 'Napa Solano 2025 Q1.pdf'
#   Renaming: 'Nashville.pdf' -> 'Nashville 2025 Q1.pdf'
#   Renaming: 'New York City.pdf' -> 'New York City 2025 Q1.pdf'
#   Renaming: 'Norfolk.pdf' -> 'Norfolk 2025 Q1.pdf'
#   Renaming: 'North East Contra Costa County.pdf' -> 'North East Contra Costa County 2025 Q1.pdf'
#   Renaming: 'Northern and Central New Jersey.pdf' -> 'Northern and Central New Jersey 2025 Q1.pdf'
#   Renaming: 'Northern Virginia.pdf' -> 'Northern Virginia 2025 Q1.pdf'
#   Renaming: 'Oakland.pdf' -> 'Oakland 2025 Q1.pdf'
#   Renaming: 'Omaha.pdf' -> 'Omaha 2025 Q1.pdf'
#   Renaming: 'Orange County.pdf' -> 'Orange County 2025 Q1.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2025 Q1.pdf'
#   Renaming: 'PA I-78 I-81 Corridor.pdf' -> 'PA I-78 I-81 Corridor 2025 Q1.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2025 Q1.pdf'
#   Renaming: 'Philadelphia.pdf' -> 'Philadelphia 2025 Q1.pdf'
#   Renaming: 'Phoenix.pdf' -> 'Phoenix 2025 Q1.pdf'
#   Renaming: 'Pittsburgh.pdf' -> 'Pittsburgh 2025 Q1.pdf'
#   Renaming: 'Polk.pdf' -> 'Polk 2025 Q1.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2025 Q1.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2025 Q1.pdf'
#   Renaming: 'Raleigh Durham.pdf' -> 'Raleigh Durham 2025 Q1.pdf'
#   Renaming: 'Reno.pdf' -> 'Reno 2025 Q1.pdf'
#   Renaming: 'Richmond.pdf' -> 'Richmond 2025 Q1.pdf'
#   Renaming: 'Sacramento.pdf' -> 'Sacramento 2025 Q1.pdf'
#   Renaming: 'Salt Lake City.pdf' -> 'Salt Lake City 2025 Q1.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2025 Q1.pdf'
#   Renaming: 'San Diego.pdf' -> 'San Diego 2025 Q1.pdf'
#   Renaming: 'San Francisco Peninsula.pdf' -> 'San Francisco Peninsula 2025 Q1.pdf'
#   Renaming: 'San Francisco.pdf' -> 'San Francisco 2025 Q1.pdf'
#   Renaming: 'Silicon Valley Snapshot.pdf' -> 'Silicon Valley Snapshot 2025 Q1.pdf'
#   Renaming: 'South Central Valley.pdf' -> 'South Central Valley 2025 Q1.pdf'
#   Renaming: 'St Louis.pdf' -> 'St Louis 2025 Q1.pdf'
#   Renaming: 'Suburban Maryland.pdf' -> 'Suburban Maryland 2025 Q1.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2025 Q1.pdf'
#   Renaming: 'Tri Valley.pdf' -> 'Tri Valley 2025 Q1.pdf'
#   Renaming: 'Tucson.pdf' -> 'Tucson 2025 Q1.pdf'
#   Renaming: 'Ventura.pdf' -> 'Ventura 2025 Q1.pdf'
# ---------------------------------------------
# --- Processing valid folder: pdf_data\2025\2025 Q2 ---
#   Renaming: 'Albuquerque.pdf' -> 'Albuquerque 2025 Q2.pdf'
#   Renaming: 'Atlanta.pdf' -> 'Atlanta 2025 Q2.pdf'
#   Renaming: 'Austin.pdf' -> 'Austin 2025 Q2.pdf'
#   Renaming: 'Baltimore.pdf' -> 'Baltimore 2025 Q2.pdf'
#   Renaming: 'Boston.pdf' -> 'Boston 2025 Q2.pdf'
#   Renaming: 'Broward.pdf' -> 'Broward 2025 Q2.pdf'
#   Renaming: 'Central Valley.pdf' -> 'Central Valley 2025 Q2.pdf'
#   Renaming: 'Chicago.pdf' -> 'Chicago 2025 Q2.pdf'
#   Renaming: 'Cincinnati.pdf' -> 'Cincinnati 2025 Q2.pdf'
#   Renaming: 'Cleveland.pdf' -> 'Cleveland 2025 Q2.pdf'
#   Renaming: 'Columbus.pdf' -> 'Columbus 2025 Q2.pdf'
#   Renaming: 'Dallas Fort Worth.pdf' -> 'Dallas Fort Worth 2025 Q2.pdf'
#   Renaming: 'Denver.pdf' -> 'Denver 2025 Q2.pdf'
#   Renaming: 'Des Moines.pdf' -> 'Des Moines 2025 Q2.pdf'
#   Renaming: 'Detroit.pdf' -> 'Detroit 2025 Q2.pdf'
#   Renaming: 'El Paso.pdf' -> 'El Paso 2025 Q2.pdf'
#   Renaming: 'Greater Los Angeles Snapshot.pdf' -> 'Greater Los Angeles Snapshot 2025 Q2.pdf'
#   Renaming: 'Greater Los Angeles.pdf' -> 'Greater Los Angeles 2025 Q2.pdf'
#   Renaming: 'Hartford.pdf' -> 'Hartford 2025 Q2.pdf'
#   Renaming: 'Houston.pdf' -> 'Houston 2025 Q2.pdf'
#   Renaming: 'Jacksonville.pdf' -> 'Jacksonville 2025 Q2.pdf'
#   Renaming: 'Kansas City.pdf' -> 'Kansas City 2025 Q2.pdf'
#   Renaming: 'Las Vegas.pdf' -> 'Las Vegas 2025 Q2.pdf'
#   Renaming: 'Long Island.pdf' -> 'Long Island 2025 Q2.pdf'
#   Renaming: 'Louisville.pdf' -> 'Louisville 2025 Q2.pdf'
#   Renaming: 'McAllen.pdf' -> 'McAllen 2025 Q2.pdf'
#   Renaming: 'Memphis.pdf' -> 'Memphis 2025 Q2.pdf'
#   Renaming: 'Miami.pdf' -> 'Miami 2025 Q2.pdf'
#   Renaming: 'Milwaukee.pdf' -> 'Milwaukee 2025 Q2.pdf'
#   Renaming: 'Minneapolis St Paul.pdf' -> 'Minneapolis St Paul 2025 Q2.pdf'
#   Renaming: 'Napa Solano County.pdf' -> 'Napa Solano County 2025 Q2.pdf'
#   Renaming: 'New York City.pdf' -> 'New York City 2025 Q2.pdf'
#   Renaming: 'Norfolk.pdf' -> 'Norfolk 2025 Q2.pdf'
#   Renaming: 'North East Contra Costa County.pdf' -> 'North East Contra Costa County 2025 Q2.pdf'
#   Renaming: 'Northern and Central New Jersey.pdf' -> 'Northern and Central New Jersey 2025 Q2.pdf'
#   Renaming: 'Northern Virginia.pdf' -> 'Northern Virginia 2025 Q2.pdf'
#   Renaming: 'Oakland.pdf' -> 'Oakland 2025 Q2.pdf'
#   Renaming: 'Omaha.pdf' -> 'Omaha 2025 Q2.pdf'
#   Renaming: 'Orlando.pdf' -> 'Orlando 2025 Q2.pdf'
#   Renaming: 'PA I-78 I-81 Corridor.pdf' -> 'PA I-78 I-81 Corridor 2025 Q2.pdf'
#   Renaming: 'Palm Beach.pdf' -> 'Palm Beach 2025 Q2.pdf'
#   Renaming: 'Philadelphia.pdf' -> 'Philadelphia 2025 Q2.pdf'
#   Renaming: 'Phoenix.pdf' -> 'Phoenix 2025 Q2.pdf'
#   Renaming: 'Pittsburgh.pdf' -> 'Pittsburgh 2025 Q2.pdf'
#   Renaming: 'Polk.pdf' -> 'Polk 2025 Q2.pdf'
#   Renaming: 'Portland.pdf' -> 'Portland 2025 Q2.pdf'
#   Renaming: 'Puget Sound.pdf' -> 'Puget Sound 2025 Q2.pdf'
#   Renaming: 'Reno.pdf' -> 'Reno 2025 Q2.pdf'
#   Renaming: 'Richmond.pdf' -> 'Richmond 2025 Q2.pdf'
#   Renaming: 'Sacramento.pdf' -> 'Sacramento 2025 Q2.pdf'
#   Renaming: 'Salt Lake City.pdf' -> 'Salt Lake City 2025 Q2.pdf'
#   Renaming: 'San Antonio.pdf' -> 'San Antonio 2025 Q2.pdf'
#   Renaming: 'San Diego.pdf' -> 'San Diego 2025 Q2.pdf'
#   Renaming: 'San Francisco Peninsula.pdf' -> 'San Francisco Peninsula 2025 Q2.pdf'
#   Renaming: 'San Francisco.pdf' -> 'San Francisco 2025 Q2.pdf'
#   Renaming: 'Silicon Valley.pdf' -> 'Silicon Valley 2025 Q2.pdf'
#   Renaming: 'South Central Valley.pdf' -> 'South Central Valley 2025 Q2.pdf'
#   Renaming: 'St Louis.pdf' -> 'St Louis 2025 Q2.pdf'
#   Renaming: 'Suburban Maryland.pdf' -> 'Suburban Maryland 2025 Q2.pdf'
#   Renaming: 'Tampa.pdf' -> 'Tampa 2025 Q2.pdf'
#   Renaming: 'Tri Valley.pdf' -> 'Tri Valley 2025 Q2.pdf'
# ---------------------------------------------
#
# Scan complete.
