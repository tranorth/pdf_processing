# %%
import pandas as pd

def standardize_market_data_final(df):
    """
    Cleans and standardizes only the 'Market' and 'Submarket' columns.
    This version correctly handles interstates even when not preceded by a space.
    """
    # Create copies to work with
    market_col = df['Market'].astype(str).copy()
    submarket_col = df['Submarket'].astype(str).copy()

    # Comprehensive dictionary for standardizing abbreviations
    abbreviations = {
        # Directions
        r'\bN\b': 'North',
        r'\bS\b': 'South',
        r'\bE\b': 'East',
        r'\bW\b': 'West',
        r'\bNe\b': 'Northeast',
        r'\bNw\b': 'Northwest',
        r'\bSe\b': 'Southeast',
        r'\bSw\b': 'Southwest',
        # Common terms
        r'\bSt\b': 'Saint',
        r'\bFt\b': 'Fort',
        r'\bBalt\b': 'Baltimore',
        r'&': 'and'
    }

    # Apply standardization steps to only the Market and Submarket columns
    for col in [market_col, submarket_col]:
        # 1. Start with lowercase and strip whitespace
        col = col.str.lower().str.strip()

        # 2. NEW: Convert '1-' to 'i-' at the start. Handles "Atlanta1-" -> "atlantai-"
        col = col.str.replace('1-', 'i-', regex=False)
        
        # 3. Remove periods that are not part of a specific acronym (like d.c.)
        col = col.str.replace(r'\.(?!\s*c\.)', '', regex=True)

        # 4. Standardize punctuation - NOTE: We now leave hyphens alone.
        col = col.str.replace(r'[/–]', ' ', regex=True)

        # 5. Apply title case. This correctly converts "i-" to "I-"
        col = col.str.title()
        
        # 6. Replace known abbreviations from the dictionary
        for abbr, full_word in abbreviations.items():
            col = col.str.replace(abbr, full_word, regex=True)
        
        # 7. Final cleanup of extra spaces
        col = col.str.replace(r'\s+', ' ', regex=True).str.strip()

    # Add the cleaned columns back to the original DataFrame
    df['Market_Cleaned'] = market_col
    df['Submarket_Cleaned'] = submarket_col
    df['Market_Submarket_Cleaned'] = df['Market_Cleaned'] + '_' + df['Submarket_Cleaned']

    return df

# %%
df = pd.read_csv('combined.csv')

# %%
print(df)
# Out:
#      Broker  Year Period_Type  Period_Number      Market  \
# 0      CBRE  2021           Q              1    Savannah
# 1      CBRE  2021           Q              2    Savannah
# 2      CBRE  2021           Q              2  Tri Valley
# 3      CBRE  2021           Q              2  Tri Valley
# 4      CBRE  2021           Q              2  Tri Valley
# ...     ...   ...         ...            ...         ...
# 8764   CBRE  2025           Q              2  Tri Valley
# 8765   CBRE  2025           Q              2  Tri Valley
# 8766   CBRE  2025           Q              2  Tri Valley
# 8767   CBRE  2025           Q              2  Tri Valley
# 8768   CBRE  2025           Q              2  Tri Valley
#
#                          Submarket Secondary Submarket  Property Type  \
# 0                  Savannah Market                 NaN        Overall
# 1                  Savannah Market                 NaN        Overall
# 2                           Dublin                 NaN     Industrial
# 3                           Dublin                 NaN      Warehouse
# 4                           Dublin                 NaN  Manufacturing
# ...                            ...                 ...            ...
# 8764                     San Ramon                 NaN      Warehouse
# 8765                     San Ramon                 NaN  Manufacturing
# 8766  Tri-Valley Ind. Market Total                 NaN     Industrial
# 8767  Tri-Valley Ind. Market Total                 NaN      Warehouse
# 8768  Tri-Valley Ind. Market Total                 NaN  Manufacturing
#
#       Inventory SF  Vacancy Q  Net Absorption Q  Under Construction Q  \
# 0       77228420.0      0.033          762012.0             8510808.0
# 1       79163460.0      0.035         2679277.0             9137976.0
# 2        1316832.0      0.023               0.0                   NaN
# 3        1266192.0      0.024               0.0                   NaN
# 4          50640.0      0.000               0.0                   NaN
# ...            ...        ...               ...                   ...
# 8764      983969.0      0.007           -2834.0                   NaN
# 8765           NaN        NaN               NaN                   NaN
# 8766    20204357.0      0.075         -117168.0              760243.0
# 8767    17342161.0      0.072          -94837.0              760243.0
# 8768     2862196.0      0.098          -22331.0                   NaN
#
#       Asking Rent Q  Delivered Q  Leasing Activity Q
# 0              5.39          NaN                 NaN
# 1              5.40    1935040.0                 NaN
# 2              0.90          NaN                 NaN
# 3              0.90          NaN                 NaN
# 4              0.95          NaN                 NaN
# ...             ...          ...                 ...
# 8764           2.19          NaN                 NaN
# 8765            NaN          NaN                 NaN
# 8766           1.17          NaN                 NaN
# 8767           1.18          NaN                 NaN
# 8768           1.10          NaN                 NaN
#
# [8769 rows x 15 columns]

# %%
standardize_market_data_final(df)
# Out:
#      Broker  Year Period_Type  Period_Number      Market  \
# 0      CBRE  2021           Q              1    Savannah
# 1      CBRE  2021           Q              2    Savannah
# 2      CBRE  2021           Q              2  Tri Valley
# 3      CBRE  2021           Q              2  Tri Valley
# 4      CBRE  2021           Q              2  Tri Valley
# ...     ...   ...         ...            ...         ...
# 8764   CBRE  2025           Q              2  Tri Valley
# 8765   CBRE  2025           Q              2  Tri Valley
# 8766   CBRE  2025           Q              2  Tri Valley
# 8767   CBRE  2025           Q              2  Tri Valley
# 8768   CBRE  2025           Q              2  Tri Valley
#
#                          Submarket Secondary Submarket  Property Type  \
# 0                  Savannah Market                 NaN        Overall
# 1                  Savannah Market                 NaN        Overall
# 2                           Dublin                 NaN     Industrial
# 3                           Dublin                 NaN      Warehouse
# 4                           Dublin                 NaN  Manufacturing
# ...                            ...                 ...            ...
# 8764                     San Ramon                 NaN      Warehouse
# 8765                     San Ramon                 NaN  Manufacturing
# 8766  Tri-Valley Ind. Market Total                 NaN     Industrial
# 8767  Tri-Valley Ind. Market Total                 NaN      Warehouse
# 8768  Tri-Valley Ind. Market Total                 NaN  Manufacturing
#
#       Inventory SF  Vacancy Q  Net Absorption Q  Under Construction Q  \
# 0       77228420.0      0.033          762012.0             8510808.0
# 1       79163460.0      0.035         2679277.0             9137976.0
# 2        1316832.0      0.023               0.0                   NaN
# 3        1266192.0      0.024               0.0                   NaN
# 4          50640.0      0.000               0.0                   NaN
# ...            ...        ...               ...                   ...
# 8764      983969.0      0.007           -2834.0                   NaN
# 8765           NaN        NaN               NaN                   NaN
# 8766    20204357.0      0.075         -117168.0              760243.0
# 8767    17342161.0      0.072          -94837.0              760243.0
# 8768     2862196.0      0.098          -22331.0                   NaN
#
#       Asking Rent Q  Delivered Q  Leasing Activity Q Market_Cleaned  \
# 0              5.39          NaN                 NaN       Savannah
# 1              5.40    1935040.0                 NaN       Savannah
# 2              0.90          NaN                 NaN     Tri Valley
# 3              0.90          NaN                 NaN     Tri Valley
# 4              0.95          NaN                 NaN     Tri Valley
# ...             ...          ...                 ...            ...
# 8764           2.19          NaN                 NaN     Tri Valley
# 8765            NaN          NaN                 NaN     Tri Valley
# 8766           1.17          NaN                 NaN     Tri Valley
# 8767           1.18          NaN                 NaN     Tri Valley
# 8768           1.10          NaN                 NaN     Tri Valley
#
#                  Submarket_Cleaned                 Market_Submarket_Cleaned
# 0                  Savannah Market                 Savannah_Savannah Market
# 1                  Savannah Market                 Savannah_Savannah Market
# 2                           Dublin                        Tri Valley_Dublin
# 3                           Dublin                        Tri Valley_Dublin
# 4                           Dublin                        Tri Valley_Dublin
# ...                            ...                                      ...
# 8764                     San Ramon                     Tri Valley_San Ramon
# 8765                     San Ramon                     Tri Valley_San Ramon
# 8766  Tri-Valley Ind. Market Total  Tri Valley_Tri-Valley Ind. Market Total
# 8767  Tri-Valley Ind. Market Total  Tri Valley_Tri-Valley Ind. Market Total
# 8768  Tri-Valley Ind. Market Total  Tri Valley_Tri-Valley Ind. Market Total
#
# [8769 rows x 18 columns]

# %%
print(df)
# Out:
#      Broker  Year Period_Type  Period_Number      Market  \
# 0      CBRE  2021           Q              1    Savannah
# 1      CBRE  2021           Q              2    Savannah
# 2      CBRE  2021           Q              2  Tri Valley
# 3      CBRE  2021           Q              2  Tri Valley
# 4      CBRE  2021           Q              2  Tri Valley
# ...     ...   ...         ...            ...         ...
# 8764   CBRE  2025           Q              2  Tri Valley
# 8765   CBRE  2025           Q              2  Tri Valley
# 8766   CBRE  2025           Q              2  Tri Valley
# 8767   CBRE  2025           Q              2  Tri Valley
# 8768   CBRE  2025           Q              2  Tri Valley
#
#                          Submarket Secondary Submarket  Property Type  \
# 0                  Savannah Market                 NaN        Overall
# 1                  Savannah Market                 NaN        Overall
# 2                           Dublin                 NaN     Industrial
# 3                           Dublin                 NaN      Warehouse
# 4                           Dublin                 NaN  Manufacturing
# ...                            ...                 ...            ...
# 8764                     San Ramon                 NaN      Warehouse
# 8765                     San Ramon                 NaN  Manufacturing
# 8766  Tri-Valley Ind. Market Total                 NaN     Industrial
# 8767  Tri-Valley Ind. Market Total                 NaN      Warehouse
# 8768  Tri-Valley Ind. Market Total                 NaN  Manufacturing
#
#       Inventory SF  Vacancy Q  Net Absorption Q  Under Construction Q  \
# 0       77228420.0      0.033          762012.0             8510808.0
# 1       79163460.0      0.035         2679277.0             9137976.0
# 2        1316832.0      0.023               0.0                   NaN
# 3        1266192.0      0.024               0.0                   NaN
# 4          50640.0      0.000               0.0                   NaN
# ...            ...        ...               ...                   ...
# 8764      983969.0      0.007           -2834.0                   NaN
# 8765           NaN        NaN               NaN                   NaN
# 8766    20204357.0      0.075         -117168.0              760243.0
# 8767    17342161.0      0.072          -94837.0              760243.0
# 8768     2862196.0      0.098          -22331.0                   NaN
#
#       Asking Rent Q  Delivered Q  Leasing Activity Q Market_Cleaned  \
# 0              5.39          NaN                 NaN       Savannah
# 1              5.40    1935040.0                 NaN       Savannah
# 2              0.90          NaN                 NaN     Tri Valley
# 3              0.90          NaN                 NaN     Tri Valley
# 4              0.95          NaN                 NaN     Tri Valley
# ...             ...          ...                 ...            ...
# 8764           2.19          NaN                 NaN     Tri Valley
# 8765            NaN          NaN                 NaN     Tri Valley
# 8766           1.17          NaN                 NaN     Tri Valley
# 8767           1.18          NaN                 NaN     Tri Valley
# 8768           1.10          NaN                 NaN     Tri Valley
#
#                  Submarket_Cleaned                 Market_Submarket_Cleaned
# 0                  Savannah Market                 Savannah_Savannah Market
# 1                  Savannah Market                 Savannah_Savannah Market
# 2                           Dublin                        Tri Valley_Dublin
# 3                           Dublin                        Tri Valley_Dublin
# 4                           Dublin                        Tri Valley_Dublin
# ...                            ...                                      ...
# 8764                     San Ramon                     Tri Valley_San Ramon
# 8765                     San Ramon                     Tri Valley_San Ramon
# 8766  Tri-Valley Ind. Market Total  Tri Valley_Tri-Valley Ind. Market Total
# 8767  Tri-Valley Ind. Market Total  Tri Valley_Tri-Valley Ind. Market Total
# 8768  Tri-Valley Ind. Market Total  Tri Valley_Tri-Valley Ind. Market Total
#
# [8769 rows x 18 columns]

# %%
# df.to_csv('fixed_combined.csv')

# %%
new_df = pd.read_csv("CBRE_ArcGIS_data.csv")

# %%
standardize_market_data_final(new_df)
# Out:
#      FID        Submarket                 Market         Market_Cleaned  \
# 0      0           Albany                 Albany                 Albany
# 1      1         Columbia                 Albany                 Albany
# 2      2           Fulton                 Albany                 Albany
# 3      3           Greene                 Albany                 Albany
# 4      4       Montgomery                 Albany                 Albany
# ..   ...              ...                    ...                    ...
# 814  814
# 815  815        Frederick      Suburban Maryland      Suburban Maryland
# 816  816
# 817  817  Harrisburg/York  PA I-78/I-81 Corridor  PA I-78/I-81 Corridor
# 818  818         Scranton  PA I-78/I-81 Corridor  PA I-78/I-81 Corridor
#
#     Submarket_Cleaned               Market_Submarket_Cleaned
# 0              Albany                          Albany_Albany
# 1            Columbia                        Albany_Columbia
# 2              Fulton                          Albany_Fulton
# 3              Greene                          Albany_Greene
# 4          Montgomery                      Albany_Montgomery
# ..                ...                                    ...
# 814                                                       _
# 815         Frederick            Suburban Maryland_Frederick
# 816                                                       _
# 817   Harrisburg/York  PA I-78/I-81 Corridor_Harrisburg/York
# 818          Scranton         PA I-78/I-81 Corridor_Scranton
#
# [819 rows x 6 columns]

# %%
new_df.to_csv("fixed_CBRE_ArcGIS_data.csv")
