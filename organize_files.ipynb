# %%
from pathlib import Path
import re
import shutil

def organize_files(source_str, target_str='organized_files'):
    """
    Finds and copies PDF files using the pathlib library.
    """
    source_path = Path(source_str)
    target_path = Path(target_str)
    target_path.mkdir(exist_ok=True) # Create the main output folder

    # The same regex pattern from before
    pattern = re.compile(r'^(.*?) \s+ 202\d \s+ [QH]\d \.pdf$', re.IGNORECASE)
    
    copied_count = 0
    print(f"✅ Searching for PDFs in '{source_path.resolve()}'...")

    # Path.rglob('*.pdf') recursively finds all files ending in .pdf
    for pdf_file in source_path.rglob('*.pdf'):
        # We match against the filename only, not the whole path
        match = pattern.match(pdf_file.name)
        
        if match:
            name = match.group(1).strip()
            
            # Create the new name-specific folder
            name_folder = target_path / name
            name_folder.mkdir(exist_ok=True)
            
            # Copy the file
            shutil.copy2(pdf_file, name_folder / pdf_file.name)
            print(f"    -> Copied '{pdf_file.name}' to '{name}' folder")
            copied_count += 1
            
    if copied_count > 0:
        print(f"\n✨ Process complete! Successfully copied {copied_count} files.")
    else:
        print("\n🤔 No matching PDF files were found to organize.")

# %%
organize_files(r"pdf_data", r"Markets")
# Out:
# ✅ Searching for PDFs in 'C:\Users\TravonCross\Documents\Git\Personal Projects\Python\pdf_processing\pdf_data'...
#
# 🤔 No matching PDF files were found to organize.

# %%
import os
import re

# --- PASTE THE FULL, ABSOLUTE PATH to your folder below ---
source_directory = 'pdf_data'

# This pattern matches names with or without a .pdf extension
pattern = re.compile(r'^(.*?) \s+ 202\d \s+ [QH]\d.*\.pdf$', re.IGNORECASE)

print("--- Starting Diagnostic ---")
print(f"🔎 Searching in folder: {source_directory}\n")

# --- Logic to find and check files ---
found_any_files = False
matched_any_files = False

if not os.path.isdir(source_directory):
    print(f"❌ ERROR: The path '{source_directory}' does not exist or is not a directory.")
else:
    for root, _, files in os.walk(source_directory):
        print(f"📂 Checking in folder: {root}")
        if not files:
            print("   -> No files here.")
        
        for filename in files:
            found_any_files = True
            match = pattern.match(filename)
            if match:
                matched_any_files = True
                print(f"   -> Found: '{filename}' ... ✅ MATCH!")
            else:
                print(f"   -> Found: '{filename}' ... ❌ No Match.")

    print("\n--- Diagnostic Complete ---")
    if not found_any_files:
        print("❗️ Result: The script did not find ANY files. Check your source_directory path.")
    elif not matched_any_files:
        print("❗️ Result: Found files, but NONE matched the required name pattern. Check your filenames.")
    else:
        print("✅ Result: The script found and matched files. The original script should work.")
# Out:
# --- Starting Diagnostic ---
# 🔎 Searching in folder: pdf_data
#
# 📂 Checking in folder: pdf_data
#    -> Found: 'Savannah 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Savannah 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Savannah 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Savannah 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Savannah 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Savannah 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Savannah 2025 Q1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2021
#    -> No files here.
# 📂 Checking in folder: pdf_data\2021\2021 Q1
#    -> Found: 'Boston 2021 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley Snapshot 2021 Q.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2021\2021 Q1 csvs
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley Snapshot.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2021\2021 Q2
#    -> Found: 'Tri Valley 2021 Q2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2021\2021 Q2 csvs
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Tri Valley.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2021\2021 Q3
#    -> Found: 'San Francisco Peninsula Snapshot 2021 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2021 Q3.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2021\2021 Q3 csvs
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2021\2021 Q4
#    -> No files here.
# 📂 Checking in folder: pdf_data\2021\2021 Q4 csvs
#    -> Found: 'Savannah.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022
#    -> No files here.
# 📂 Checking in folder: pdf_data\2022\2022 H1
#    -> Found: 'Oklahoma_City H1 2022.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2022 H1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 H1 csvs
#    -> Found: 'Oklahoma City.csv' ... ❌ No Match.
#    -> Found: 'tulsa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 H2
#    -> Found: 'Colorado Springs 2022 H2.pdf' ... ❌ No Match.
#    -> Found: 'Norfolk 2022 H2.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2022 H2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 H2 csvs
#    -> Found: 'Colorado Springs.csv' ... ❌ No Match.
#    -> Found: 'Norfolk.csv' ... ❌ No Match.
#    -> Found: 'Tulsa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q1
#    -> Found: 'Boston 2022 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2022 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh Durham 2022 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2022 Q1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q1 csvs
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q2
#    -> Found: 'Grand Rapids 2022 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Polk County 2022 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2022 Q2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q2 csvs
#    -> Found: 'Grand Rapids.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Tulsa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q3
#    -> Found: 'Raleigh Durham 2022 Q3.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q3 csvs
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q4
#    -> Found: 'Austin 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Bay Area 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Central Valley 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Charlotte 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Columbus 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Dayton 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Memphis 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Minneapolis 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Napa-Solano 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'New York City 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Omaha 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburgh 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Polk County 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sound 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh Durham 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley Snapshot 2022 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Suburban Maryland 2022 Q4.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2022\2022 Q4 csvs
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Baltimore.csv' ... ❌ No Match.
#    -> Found: 'Bay Area.csv' ... ❌ No Match.
#    -> Found: 'Central Valley.csv' ... ❌ No Match.
#    -> Found: 'Charlotte.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Columbus.csv' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth.csv' ... ❌ No Match.
#    -> Found: 'Dayton.csv' ... ❌ No Match.
#    -> Found: 'Denver.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Memphis.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Minneapolis.csv' ... ❌ No Match.
#    -> Found: 'Napa Solano.csv' ... ❌ No Match.
#    -> Found: 'New York City.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Oakland.csv' ... ❌ No Match.
#    -> Found: 'Omaha.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley.csv' ... ❌ No Match.
#    -> Found: 'Suburban Maryland.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023
#    -> Found: 'Jackson 2023.pdf' ... ❌ No Match.
#    -> Found: 'Jackson.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 H1
#    -> Found: 'Oklahoma City 2023 H1.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2023 H1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 H1 csvs
#    -> Found: 'Oklahoma City.csv' ... ❌ No Match.
#    -> Found: 'Tulsa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 H2
#    -> Found: 'Colorado Springs 2023 H2.pdf' ... ❌ No Match.
#    -> Found: 'Northern Colorado 2023 H2.pdf' ... ❌ No Match.
#    -> Found: 'Oklahoma City 2023 H2.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2023 H2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 H2 csvs
#    -> Found: 'Colorado Springs.csv' ... ❌ No Match.
#    -> Found: 'Northern Colorado.csv' ... ❌ No Match.
#    -> Found: 'Oklahoma City.csv' ... ❌ No Match.
#    -> Found: 'Tulsa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q1
#    -> Found: 'Atlanta 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Boise 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Charleston 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Indianapolis 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Las Vegas 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Louisville 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Memphis 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Nashville 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Northern VA 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Omaha 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Orange County 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburgh 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Polk County 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sound 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh Durham 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Reno 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Salt Lake City 2023 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley 2023 Q1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q1 csvs
#    -> Found: 'Atlanta.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Boise.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Charleston.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth.csv' ... ❌ No Match.
#    -> Found: 'Denver.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'El Paso.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Indianapolis.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'Las Vegas.csv' ... ❌ No Match.
#    -> Found: 'Louisville.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Memphis.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Nashville.csv' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Omaha.csv' ... ❌ No Match.
#    -> Found: 'Orange County.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Sacramento Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Salt Lake City.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q2
#    -> Found: 'Albuquerque 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Atlanta 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Boise 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Central Valley 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Charleston 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Charlotte 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Colorado Springs 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Columbus 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Hartford 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Indianapolis 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Long Island 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Louisville 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Memphis 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Minneapolis 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Napa Solano 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Nashville 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'New York City 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Northern California Do Alone 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Omaha 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Orange County 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Phoenix 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburg 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Polk County 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sound 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Reno 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento Snapshot 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Salt Lake City 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'South Central Valley 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'St Louis 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tri Valley 2023 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tucson 2023 Q2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q2 csvs
#    -> Found: 'Albuquerque.csv' ... ❌ No Match.
#    -> Found: 'Atlanta.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Baltimore.csv' ... ❌ No Match.
#    -> Found: 'Boise.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Central Valley.csv' ... ❌ No Match.
#    -> Found: 'Charleston.csv' ... ❌ No Match.
#    -> Found: 'Charlotte.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Colorado Springs.csv' ... ❌ No Match.
#    -> Found: 'Columbus.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'El Paso.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Hartford.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Indianapolis.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'Long Island.csv' ... ❌ No Match.
#    -> Found: 'Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Louisville.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Memphis.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Minneapolis.csv' ... ❌ No Match.
#    -> Found: 'Napa Solano.csv' ... ❌ No Match.
#    -> Found: 'Nashville.csv' ... ❌ No Match.
#    -> Found: 'New York City.csv' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Oakland.csv' ... ❌ No Match.
#    -> Found: 'Omaha.csv' ... ❌ No Match.
#    -> Found: 'Orange County.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'Phoenix.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Sacramento Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'Salt Lake City.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'San Francisco.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley.csv' ... ❌ No Match.
#    -> Found: 'South Central Valley.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'Tri Valley.csv' ... ❌ No Match.
#    -> Found: 'Tucson.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q3
#    -> Found: 'Boston 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Columbia 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'New York City 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'North East 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Orange County 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Polk County 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'St Louis 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2023 Q3.pdf' ... ❌ No Match.
#    -> Found: 'United States 2023 Q3.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q3 csvs
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Columbia.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'New York City.csv' ... ❌ No Match.
#    -> Found: 'North East.csv' ... ❌ No Match.
#    -> Found: 'Orange County.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'United States.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q4
#    -> Found: 'Albuquerque 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Charleston 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Hartford 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Indianapolis 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Minneapolis 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Nashville 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Norfolk 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Orange County 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Philadelphia 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Phoenix 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburg 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Polk County 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sount 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh Durham 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Reno 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Richmond 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento Snapshot 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Salt Lake City 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'San Diego 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco Penninsuka 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Savannah 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'South Central Valley 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'St Louis 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Tucson 2023 Q4.pdf' ... ❌ No Match.
#    -> Found: 'United States 2023 Q4.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2023\2023 Q4 csvs
#    -> Found: 'Albuquerque.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Baltimore.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Charleston.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth.csv' ... ❌ No Match.
#    -> Found: 'Denver.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'El Paso.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem.csv' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg.csv' ... ❌ No Match.
#    -> Found: 'Hartford.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Indianapolis.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Minneapolis.csv' ... ❌ No Match.
#    -> Found: 'Nashville.csv' ... ❌ No Match.
#    -> Found: 'Norfolk.csv' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County.csv' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Oakland.csv' ... ❌ No Match.
#    -> Found: 'Orange County.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'Philadelphia.csv' ... ❌ No Match.
#    -> Found: 'Phoenix.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Richmond.csv' ... ❌ No Match.
#    -> Found: 'Sacramento Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'Salt Lake City.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Diego.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'San Francisco.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'South Central Valley.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'Tucson.csv' ... ❌ No Match.
#    -> Found: 'United States.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024
#    -> No files here.
# 📂 Checking in folder: pdf_data\2024\2024 H1
#    -> Found: 'Colorado Springs 2024 H1.pdf' ... ❌ No Match.
#    -> Found: 'Northern Colorado 2024 H1.pdf' ... ❌ No Match.
#    -> Found: 'Oklahoma City 2024 H1.pdf' ... ❌ No Match.
#    -> Found: 'Panhandle 2024 H1.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2024 H1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 H1 csvs
#    -> Found: 'Colorado Springs.csv' ... ❌ No Match.
#    -> Found: 'Northern Colorado.csv' ... ❌ No Match.
#    -> Found: 'Oklahoma City.csv' ... ❌ No Match.
#    -> Found: 'Panhandle.csv' ... ❌ No Match.
#    -> Found: 'Tulsa.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 H2
#    -> Found: 'Colorado Springs 2024 H2.pdf' ... ❌ No Match.
#    -> Found: 'Northern Colorado 2024 H2.pdf' ... ❌ No Match.
#    -> Found: 'Oklahoma City 2024 Q2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 H2 csvs
#    -> Found: 'Colorado Springs.csv' ... ❌ No Match.
#    -> Found: 'Northern Colorado.csv' ... ❌ No Match.
#    -> Found: 'Oklahoma City.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 Q1
#    -> Found: 'Albuquerque 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Atlanta 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Boise 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Central Los Angeles 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Central Valley 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Charleston 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Columbia 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Columbus 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greater San Fernando 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Indianapolis 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Laredo 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Las Vegas 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Louisville 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Midwest 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Minneapolis 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Napa Solano 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Nashville 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'New York CIty 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Norfolk 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Northern California 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Omaha 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Orange County 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Panhandle 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Philadelphia 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Phoenix 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburgh 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sound 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Reno 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Richmond 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Gabriel Valley 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'South Bay 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'South Central Valley 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'St Louis 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Suburban Maryland 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Tri Valley 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Tucson 2024 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Ventura 2024 Q1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 Q1 csvs
#    -> Found: 'Albuquerque.csv' ... ❌ No Match.
#    -> Found: 'Atlanta.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Baltimore.csv' ... ❌ No Match.
#    -> Found: 'Boise.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Central Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Central Valley.csv' ... ❌ No Match.
#    -> Found: 'Charleston.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Columbia.csv' ... ❌ No Match.
#    -> Found: 'Columbus.csv' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth.csv' ... ❌ No Match.
#    -> Found: 'Denver.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'El Paso.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Greater San Fernando.csv' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem.csv' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Indianapolis.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'Laredo.csv' ... ❌ No Match.
#    -> Found: 'Las Vegas.csv' ... ❌ No Match.
#    -> Found: 'Louisville.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'Midwest.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Minneapolis.csv' ... ❌ No Match.
#    -> Found: 'Napa Solano.csv' ... ❌ No Match.
#    -> Found: 'Nashville.csv' ... ❌ No Match.
#    -> Found: 'New York City.csv' ... ❌ No Match.
#    -> Found: 'Norfolk.csv' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County.csv' ... ❌ No Match.
#    -> Found: 'Northern California.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Oakland.csv' ... ❌ No Match.
#    -> Found: 'Omaha.csv' ... ❌ No Match.
#    -> Found: 'Orange County.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'Philadelphia.csv' ... ❌ No Match.
#    -> Found: 'Phoenix.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Richmond.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'San Francisco.csv' ... ❌ No Match.
#    -> Found: 'San Gabriel Valley.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley.csv' ... ❌ No Match.
#    -> Found: 'South Bay.csv' ... ❌ No Match.
#    -> Found: 'South Central Valley.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Suburban Maryland.csv' ... ❌ No Match.
#    -> Found: 'Tri Valley.csv' ... ❌ No Match.
#    -> Found: 'Tucson.csv' ... ❌ No Match.
#    -> Found: 'Ventura.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 Q2
#    -> Found: 'Atlanta 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Colorado Springs 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Northern Colorado 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2024 Q2.pdf' ... ❌ No Match.
#    -> Found: 'United States 2024 Q2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 Q2 csvs
#    -> Found: 'Atlanta.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Colorado Springs.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey.csv' ... ❌ No Match.
#    -> Found: 'Northern Colorado.csv' ... ❌ No Match.
#    -> Found: 'Oakland Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'Tulsa.csv' ... ❌ No Match.
#    -> Found: 'United States.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 Q3
#    -> Found: 'Albuquerque 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Atlanta 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Boise 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Central Los Angeles 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Central Valley 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Charleston 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Charlotte 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Colorado Springs 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Columbus 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Greensboro Winston Salem 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Hartford 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Indianapolis 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire East 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire West 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Las Vegas 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Long Island 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Lousiville 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Minneapolis 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Napa Solano 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Nashville 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'New York City 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Norfolk 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Northern Colorado 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Omaha 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Orange County 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Philadelphia 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Phoenix 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburgh 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Polk 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sound 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh Durham 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Reno 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Richmond 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento Snapshot 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'San Diego 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'South Central Valley 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'St Louis 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Suburban Maryland 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Tri Valley 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Tucson 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Tulsa 2024 Q3.pdf' ... ❌ No Match.
#    -> Found: 'Ventura 2024 Q3.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 Q3 csvs
#    -> Found: 'Albuquerque.csv' ... ❌ No Match.
#    -> Found: 'Atlanta.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Baltimore.csv' ... ❌ No Match.
#    -> Found: 'Boise.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Central Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Central Valley.csv' ... ❌ No Match.
#    -> Found: 'Charleston.csv' ... ❌ No Match.
#    -> Found: 'Charlotte.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Colorado Springs.csv' ... ❌ No Match.
#    -> Found: 'Columbus.csv' ... ❌ No Match.
#    -> Found: 'Denver.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'El Paso.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem.csv' ... ❌ No Match.
#    -> Found: 'Hartford.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Indianapolis.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire East.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire West.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'Las Vegas.csv' ... ❌ No Match.
#    -> Found: 'Long Island.csv' ... ❌ No Match.
#    -> Found: 'Louisville.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Minneapolis.csv' ... ❌ No Match.
#    -> Found: 'Napa Solano.csv' ... ❌ No Match.
#    -> Found: 'Nashville.csv' ... ❌ No Match.
#    -> Found: 'New York City.csv' ... ❌ No Match.
#    -> Found: 'Norfolk.csv' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County.csv' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey.csv' ... ❌ No Match.
#    -> Found: 'Northern Colorado.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Oakland.csv' ... ❌ No Match.
#    -> Found: 'Omaha.csv' ... ❌ No Match.
#    -> Found: 'Orange County.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'Philadelphia.csv' ... ❌ No Match.
#    -> Found: 'Phoenix.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Richmond.csv' ... ❌ No Match.
#    -> Found: 'Sacramento Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Diego.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'San Francisco.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley Snap R and D.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley Snapshot.csv' ... ❌ No Match.
#    -> Found: 'South Central Valley.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Suburban Maryland.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'Tri Valley.csv' ... ❌ No Match.
#    -> Found: 'Tucson.csv' ... ❌ No Match.
#    -> Found: 'Ventura.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2024\2024 Q4
#    -> Found: 'Albuquerque 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Atlanta 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Boise 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Central Los Angeles 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Central Valley 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Charleston 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Charlotte 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Columbia 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Columbus 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Greensboro Winston Salem 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Hartford 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Indianapolis 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire East 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire West 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2024 Q4.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2024 Q4.pdf' ... ❌ No Match.
# ...
#    -> Found: 'Philadelphia.csv' ... ❌ No Match.
#    -> Found: 'Phoenix.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Port St Lucie.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Richmond.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'San Francisco.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley.csv' ... ❌ No Match.
#    -> Found: 'South Central Valley.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Suburban Maryland.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'Tri Valley.csv' ... ❌ No Match.
#    -> Found: 'Tucson.csv' ... ❌ No Match.
#    -> Found: 'Ventura.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2025
#    -> Found: 'Greater San Fernando Valley 2025 Q1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2025\2025 Q1
#    -> Found: 'Albuquerque 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Atlanta 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Boise 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Central Los Angeles 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Central Valley 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Charleston 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Charlotte 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Columbus 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greensboro Winston Salem 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Hartford 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Indianapolis 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Inland Empire 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Las Vegas 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Long Island 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Louisville 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Memphis 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Minneapolis 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Napa Solano 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Nashville 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'New York City 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Norfolk 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Omaha 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Orange County 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Philadelphia 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Phoenix 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburgh 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Polk 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sound 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Raleigh Durham 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Reno 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Richmond 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Salt Lake City 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Diego 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley Snapshot 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'South Central Valley 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'St Louis 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Suburban Maryland 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Tri Valley 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Tucson 2025 Q1.pdf' ... ❌ No Match.
#    -> Found: 'Ventura 2025 Q1.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2025\2025 Q1 csvs
#    -> Found: 'Albuquerque.csv' ... ❌ No Match.
#    -> Found: 'Atlanta.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Baltimore.csv' ... ❌ No Match.
#    -> Found: 'Boise.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Central Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Central Valley.csv' ... ❌ No Match.
#    -> Found: 'Charleston.csv' ... ❌ No Match.
#    -> Found: 'Charlotte.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Columbus.csv' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth.csv' ... ❌ No Match.
#    -> Found: 'Denver.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'El Paso.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Greater San Fernando Valley.csv' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem.csv' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg.csv' ... ❌ No Match.
#    -> Found: 'Hartford.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Indianapolis.csv' ... ❌ No Match.
#    -> Found: 'Inland Empire.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'Las Vegas.csv' ... ❌ No Match.
#    -> Found: 'Long Island.csv' ... ❌ No Match.
#    -> Found: 'Louisville.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Memphis.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Minneapolis.csv' ... ❌ No Match.
#    -> Found: 'Napa Solano.csv' ... ❌ No Match.
#    -> Found: 'Nashville.csv' ... ❌ No Match.
#    -> Found: 'New York City.csv' ... ❌ No Match.
#    -> Found: 'Norfolk.csv' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County.csv' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Oakland.csv' ... ❌ No Match.
#    -> Found: 'Omaha.csv' ... ❌ No Match.
#    -> Found: 'Orange County.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'Philadelphia.csv' ... ❌ No Match.
#    -> Found: 'Phoenix.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Raleigh Durham.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Richmond.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'Salt Lake City.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Diego.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'San Francisco.csv' ... ❌ No Match.
#    -> Found: 'Savannah.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley.csv' ... ❌ No Match.
#    -> Found: 'South Central Valley.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Suburban Maryland.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'Tri Valley.csv' ... ❌ No Match.
#    -> Found: 'Tucson.csv' ... ❌ No Match.
#    -> Found: 'Ventura.csv' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2025\2025 Q2
#    -> Found: 'Albuquerque 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Atlanta 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Austin 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Baltimore 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Boston 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Broward 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Central Valley 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Chicago 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Cincinnati 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Cleveland 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Columbus 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Denver 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Des Moines 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Detroit 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'El Paso 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Hartford 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Hawaii 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Houston 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Jacksonville 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Kansas City 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Las Vegas 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Long Island 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Louisville 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'McAllen 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Memphis 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Miami 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Midwest 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Milwaukee 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Minneapolis St Paul 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Napa Solano County 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'New York City 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Norfolk 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Northern Virginia 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Oakland 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Omaha 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Orlando 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Palm Beach 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Philadelphia 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Phoenix 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Pittsburgh 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Polk 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Portland 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Puget Sound 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Reno 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Richmond 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Sacramento 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Salt Lake City 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Antonio 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Diego 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Silicon Valley 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'South Central Valley 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'St Louis 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Suburban Maryland 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tampa 2025 Q2.pdf' ... ❌ No Match.
#    -> Found: 'Tri Valley 2025 Q2.pdf' ... ❌ No Match.
# 📂 Checking in folder: pdf_data\2025\2025 Q2 csvs
#    -> Found: 'Albuquerque.csv' ... ❌ No Match.
#    -> Found: 'Atlanta.csv' ... ❌ No Match.
#    -> Found: 'Austin.csv' ... ❌ No Match.
#    -> Found: 'Baltimore.csv' ... ❌ No Match.
#    -> Found: 'Boston.csv' ... ❌ No Match.
#    -> Found: 'Broward.csv' ... ❌ No Match.
#    -> Found: 'Central Valley.csv' ... ❌ No Match.
#    -> Found: 'Chicago.csv' ... ❌ No Match.
#    -> Found: 'Cincinnati.csv' ... ❌ No Match.
#    -> Found: 'Cleveland.csv' ... ❌ No Match.
#    -> Found: 'Columbus.csv' ... ❌ No Match.
#    -> Found: 'Dallas Fort Worth.csv' ... ❌ No Match.
#    -> Found: 'Denver.csv' ... ❌ No Match.
#    -> Found: 'Des Moines.csv' ... ❌ No Match.
#    -> Found: 'Detroit.csv' ... ❌ No Match.
#    -> Found: 'El Paso.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles Snapshot.csv' ... ❌ No Match.
#    -> Found: 'Greater Los Angeles.csv' ... ❌ No Match.
#    -> Found: 'Greensboro Winston-Salem.csv' ... ❌ No Match.
#    -> Found: 'Greenville Spartanburg.csv' ... ❌ No Match.
#    -> Found: 'Hartford.csv' ... ❌ No Match.
#    -> Found: 'Hawaii.csv' ... ❌ No Match.
#    -> Found: 'Houston.csv' ... ❌ No Match.
#    -> Found: 'Jacksonville.csv' ... ❌ No Match.
#    -> Found: 'Kansas City.csv' ... ❌ No Match.
#    -> Found: 'Las Vegas.csv' ... ❌ No Match.
#    -> Found: 'Long Island.csv' ... ❌ No Match.
#    -> Found: 'Louisville.csv' ... ❌ No Match.
#    -> Found: 'McAllen.csv' ... ❌ No Match.
#    -> Found: 'Memphis.csv' ... ❌ No Match.
#    -> Found: 'Miami.csv' ... ❌ No Match.
#    -> Found: 'Midwest.csv' ... ❌ No Match.
#    -> Found: 'Milwaukee.csv' ... ❌ No Match.
#    -> Found: 'Minneapolis.csv' ... ❌ No Match.
#    -> Found: 'Napa Solano.csv' ... ❌ No Match.
#    -> Found: 'New York City.csv' ... ❌ No Match.
#    -> Found: 'Norfolk.csv' ... ❌ No Match.
#    -> Found: 'North East Contra Costa County.csv' ... ❌ No Match.
#    -> Found: 'Northern and Central New Jersey.csv' ... ❌ No Match.
#    -> Found: 'Northern Virginia.csv' ... ❌ No Match.
#    -> Found: 'Oakland.csv' ... ❌ No Match.
#    -> Found: 'Omaha.csv' ... ❌ No Match.
#    -> Found: 'Orlando.csv' ... ❌ No Match.
#    -> Found: 'PA I-78 I-81 Corridor.csv' ... ❌ No Match.
#    -> Found: 'Palm Beach.csv' ... ❌ No Match.
#    -> Found: 'Philadelphia.csv' ... ❌ No Match.
#    -> Found: 'Phoenix.csv' ... ❌ No Match.
#    -> Found: 'Pittsburgh.csv' ... ❌ No Match.
#    -> Found: 'Polk County.csv' ... ❌ No Match.
#    -> Found: 'Portland.csv' ... ❌ No Match.
#    -> Found: 'Puget Sound.csv' ... ❌ No Match.
#    -> Found: 'Reno.csv' ... ❌ No Match.
#    -> Found: 'Richmond.csv' ... ❌ No Match.
#    -> Found: 'Sacramento.csv' ... ❌ No Match.
#    -> Found: 'Salt Lake City.csv' ... ❌ No Match.
#    -> Found: 'San Antonio.csv' ... ❌ No Match.
#    -> Found: 'San Diego.csv' ... ❌ No Match.
#    -> Found: 'San Francisco Peninsula.csv' ... ❌ No Match.
#    -> Found: 'San Francisco.csv' ... ❌ No Match.
#    -> Found: 'Silicon Valley.csv' ... ❌ No Match.
#    -> Found: 'South Central Valley.csv' ... ❌ No Match.
#    -> Found: 'St Louis.csv' ... ❌ No Match.
#    -> Found: 'Suburban Maryland.csv' ... ❌ No Match.
#    -> Found: 'Tampa.csv' ... ❌ No Match.
#    -> Found: 'Tri Valley.csv' ... ❌ No Match.
#
# --- Diagnostic Complete ---
# ❗️ Result: Found files, but NONE matched the required name pattern. Check your filenames.

# %%
from pathlib import Path
import shutil

def organize_pdfs_by_csv_names(source_dir_str, target_dir_str='organized_files'):
    """
    1. Finds all unique base names from .csv files in the source directory.
    2. Creates a folder for each unique name in the target directory.
    3. Finds all .pdf files that contain one of the unique names and copies them
       to the corresponding folder.
    """
    source_path = Path(source_dir_str)
    target_path = Path(target_dir_str)

    if not source_path.is_dir():
        print(f"❌ Error: Source directory '{source_path}' not found.")
        return

    # --- 1. First Pass: Collect all unique base names from CSV files ---
    print(f"📂 Pass 1: Searching for CSV files in '{source_path.resolve()}' to get names...")
    
    # Use a set to automatically handle duplicates
    base_names = set()
    for csv_file in source_path.rglob('*.csv'):
        # Get the filename without the .csv extension
        name = csv_file.stem 
        base_names.add(name)

    if not base_names:
        print("❗️ No CSV files found. Cannot determine which folders to create.")
        return
        
    print(f"✅ Found {len(base_names)} unique names.")

    # --- 2. Create Folders & Second Pass: Find and copy matching PDFs ---
    print(f"\n📂 Pass 2: Searching for matching PDFs to copy to '{target_path.resolve()}'...")
    target_path.mkdir(exist_ok=True) # Create the main output folder
    
    copied_count = 0
    # Iterate through each unique name found from the CSVs
    for name in sorted(list(base_names)): # Sort for predictable output
        
        # Create a specific folder for the current name
        name_folder = target_path / name
        name_folder.mkdir(exist_ok=True)
        
        # Now, find all PDFs that contain this name
        # Using rglob is efficient as it searches the whole tree
        for pdf_file in source_path.rglob('*.pdf'):
            # Check if the base name is a part of the PDF's filename
            if name in pdf_file.name:
                # Define the destination path
                destination = name_folder / pdf_file.name
                
                # Check if the file already exists to avoid re-copying
                if not destination.exists():
                    shutil.copy2(pdf_file, destination)
                    print(f"  -> Copied '{pdf_file.name}' to '{name_folder}'")
                    copied_count += 1

    print("\n--- ✨ Process Complete! ---")
    if copied_count > 0:
        print(f"Successfully organized and copied {copied_count} files.")
    else:
        print("Found names from CSVs, but no matching PDF files were found to copy.")

# --- How to run the script ---
# Set your source directory (where the 'pdf_data' folder is)
source_directory = 'pdf_data' 
# You can optionally change the name of the output folder
target_directory = 'Markets' 

organize_pdfs_by_csv_names(source_directory, target_directory)
# Out:
# 📂 Pass 1: Searching for CSV files in 'C:\Users\TravonCross\Documents\Git\Personal Projects\Python\pdf_processing\pdf_data' to get names...
# ✅ Found 104 unique names.
#
# 📂 Pass 2: Searching for matching PDFs to copy to 'C:\Users\TravonCross\Documents\Git\Personal Projects\Python\pdf_processing\Markets'...
#
# --- ✨ Process Complete! ---
# Found names from CSVs, but no matching PDF files were found to copy.
