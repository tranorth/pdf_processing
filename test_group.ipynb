# %%
import pandas as pd

# %%
cbre = pd.read_excel(r"S:\13 - DataPoint\Projects\Industrial\Broker Market Reports Parse\CBRE\Current Market Reports\csv_data\matching\CBRE_ArcGIS.xls")
combined = pd.read_excel(r"S:\13 - DataPoint\Projects\Industrial\Broker Market Reports Parse\CBRE\Current Market Reports\csv_data\matching\combined_v2.xlsx")

# %%
combined[combined["Market"] == "Northern and Central New Jersey"]
# Out:
#      Broker  Year Period_Type  Period_Number                           Market  \
# 5520   CBRE  2025           Q              1  Northern and Central New Jersey
# 5521   CBRE  2023           Q              1  Northern and Central New Jersey
# 5522   CBRE  2023           Q              1  Northern and Central New Jersey
# 5523   CBRE  2023           Q              4  Northern and Central New Jersey
# 5524   CBRE  2024           Q              2  Northern and Central New Jersey
# ...     ...   ...         ...            ...                              ...
# 5741   CBRE  2023           Q              1  Northern and Central New Jersey
# 5742   CBRE  2023           Q              1  Northern and Central New Jersey
# 5743   CBRE  2023           Q              4  Northern and Central New Jersey
# 5744   CBRE  2024           Q              3  Northern and Central New Jersey
# 5745   CBRE  2025           Q              2  Northern and Central New Jersey
#
# ...

# %%
new_df = pd.merge(combined, cbre, left_on=["Market", "Secondary Submarket"], right_on=["Market", "Submarket"], how="inner")

# %%
print(new_df[new_df["Market"] == "Northern and Central New Jersey"])
# Out:
#       Broker  Year Period_Type  Period_Number  \
# 51754   CBRE  2025           Q              1
# 51755   CBRE  2025           Q              1
# 51756   CBRE  2025           Q              1
# 51757   CBRE  2025           Q              1
# 51758   CBRE  2025           Q              1
# ...      ...   ...         ...            ...
# 57625   CBRE  2025           Q              2
# 57626   CBRE  2025           Q              2
# 57627   CBRE  2025           Q              2
# 57628   CBRE  2025           Q              2
# 57629   CBRE  2025           Q              2
#
#                                 Market                Submarket_x  \
# 51754  Northern and Central New Jersey         Central New Jersey
# 51755  Northern and Central New Jersey         Central New Jersey
# 51756  Northern and Central New Jersey         Central New Jersey
# 51757  Northern and Central New Jersey         Central New Jersey
# 51758  Northern and Central New Jersey         Central New Jersey
# ...

# %%
new_jersey = new_df[new_df["Market"] == "Northern and Central New Jersey"]
new_df[new_df["Market"] == "Northern and Central New Jersey"]
# Out:
#     Broker  Year Period_Type  Period_Number                           Market  \
# 386   CBRE  2023           Q              1  Northern and Central New Jersey
# 387   CBRE  2023           Q              1  Northern and Central New Jersey
# 388   CBRE  2023           Q              4  Northern and Central New Jersey
# 389   CBRE  2024           Q              2  Northern and Central New Jersey
# 390   CBRE  2024           Q              3  Northern and Central New Jersey
# ..     ...   ...         ...            ...                              ...
# 580   CBRE  2024           Q              2  Northern and Central New Jersey
# 581   CBRE  2024           Q              3  Northern and Central New Jersey
# 582   CBRE  2024           Q              4  Northern and Central New Jersey
# 583   CBRE  2025           Q              1  Northern and Central New Jersey
# 584   CBRE  2025           Q              2  Northern and Central New Jersey
#
# ...

# %%
new_jersey[["Market","Submarket_x", "Secondary Submarket", "Submarket_y"]]
# Out:
#                               Market          Submarket_x Secondary Submarket  \
# 386  Northern and Central New Jersey   Central New Jersey   Brunswicks/Exit 9
# 387  Northern and Central New Jersey   Central New Jersey   Brunswicks/Exit 9
# 388  Northern and Central New Jersey   Central New Jersey   Brunswicks/Exit 9
# 389  Northern and Central New Jersey   Central New Jersey   Brunswicks/Exit 9
# 390  Northern and Central New Jersey   Central New Jersey   Brunswicks/Exit 9
# ..                               ...                  ...                 ...
# 580  Northern and Central New Jersey  Northern New Jersey      Suburban Essex
# 581  Northern and Central New Jersey  Northern New Jersey      Suburban Essex
# 582  Northern and Central New Jersey  Northern New Jersey      Suburban Essex
# 583  Northern and Central New Jersey  Northern New Jersey      Suburban Essex
# 584  Northern and Central New Jersey  Northern New Jersey      Suburban Essex
#
#            Submarket_y
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)
print(new_jersey[["Market","Submarket_x", "Secondary Submarket", "Submarket_y"]].head(60))
# Out:
#                               Market         Submarket_x Secondary Submarket        Submarket_y
# 386  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 387  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 388  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 389  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 390  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 391  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 392  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 393  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# 394  Northern and Central New Jersey  Central New Jersey   Brunswicks/Exit 9  Brunswicks/Exit 9
# ...
